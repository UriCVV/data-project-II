# %%
import pandas as pd

# %%
df = pd.read_csv("../data/SmokingAndTobaccoData2018-enhanced.csv")

# %%
df
# Out:
#         Country  CigaretteSmokingPrevalence  TobaccoSmokingPrevalence  \
# 0       Albania                        43.3                      50.5
# 1       Algeria                        11.1                      14.5
# 2       Andorra                        27.7                      33.8
# 3     Argentina                        19.2                      21.1
# 4       Armenia                        19.6                      26.7
# ..          ...                         ...                       ...
# 144  Uzbekistan                        10.1                      12.3
# 145     Vanuatu                         2.4                      20.1
# 146       Yemen                        20.7                      26.9
# 147      Zambia                        11.5                      24.1
# 148    Zimbabwe                        11.1                      13.9
#
#      TobaccoUsePrevalance DeathsBySmoking HealthWarningsOnSmoking  \
# ...

# %%
df.isna().sum()
# Out:
# Country                              0
# CigaretteSmokingPrevalence           0
# TobaccoSmokingPrevalence             0
# TobaccoUsePrevalance                 0
# DeathsBySmoking                     12
# HealthWarningsOnSmoking              0
# TreatmentInHealthFacilities          0
# MostSoldBrandCigarettePriceInUSD    28
# GDPinUSD                            26
# Population                          13
# dtype: int64

# %%
df.dtypes
# Out:
# Country                              object
# CigaretteSmokingPrevalence          float64
# TobaccoSmokingPrevalence            float64
# TobaccoUsePrevalance                float64
# DeathsBySmoking                      object
# HealthWarningsOnSmoking              object
# TreatmentInHealthFacilities          object
# MostSoldBrandCigarettePriceInUSD    float64
# GDPinUSD                            float64
# Population                          float64
# dtype: object
